# %%
from splunklib import client

# %%
TOKEN = "eyJraWQiOiJzcGx1bmsuc2VjcmV0IiwiYWxnIjoiSFM1MTIiLCJ2ZXIiOiJ2MiIsInR0eXAiOiJzdGF0aWMifQ..am7v8ZfDMdEMrTwjnASnwxneQDSWj6YLWiHIy8wyIwx3zr5mQKyD4Tqms7zONrwHXq1b-Fsk58CNrzAQb0lb-Q"

# %%
service = client.connect(
        host="localhost", port=8089, username="admin", splunkToken=TOKEN, app="search"
    )

# %%
title = "Testing API Detection Creation 2"

# %%
query_string = "index=main Image='*\\google.com'"

# %%
search_params = {
    "cron_schedule": "30 * * * *",
    "description": "This is a test detection",
    "dispatch.earliest_time": "-1h",
    "dispatch.latest_time": "now",
    "is_scheduled": "1",
}

# %%
service.saved_searches.create(title, query_string, **search_params)

# %%
service.fired_alerts.get()
